# %% [markdown]
# # КНАД Python ДЗ 1: Арифметика

# %% [markdown]
# # A. Дележ яблок-1
#
# ![image.png](data:image/png;base64,...)

# %%
N = int(input())
K = int(input())

print(K // N)

# %% [markdown]
# # B. Дележ яблок-2
#
# ![image.png](data:image/png;base64,...)

# %%
N = int(input())
K = int(input())

print(K - N * (K // N))

# %% [markdown]
# # C. Степень двойки
#
# ![image.png](data:image/png;base64,...)

# %%
N = int(input())

print(2 ** N)

# %% [markdown]
# # D. Последняя цифра
#
# ![image.png](data:image/png;base64,...)

# %%
a = int(input())

print(a % 10)

# %% [markdown]
# # E. Первая цифра двузначного числа
#
# ![image.png](data:image/png;base64,...)

# %%
a = int(input())

print((a - (a % 10)) // 10)

# %% [markdown]
# # F. Вторая справа цифра
#
# ![image.png](data:image/png;base64,...)

# %%
a = int(input())

print((a % 100) // 10)

# %% [markdown]
# # G. Сумма цифр трехзначного числа
#
# ![image.png](data:image/png;base64,...)

# %%
a = int(input())

print((a % 10) + ((a % 100) // 10) + (a // 100))

# %% [markdown]
# # H. 0 в 1 и наоборот
#
# ![image.png](data:image/png;base64,...)

# %%
a = input()

if a == '0':
    print('1')
elif a == '1':
    print('0')

# %% [markdown]
# # I. Следующее четное
#
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())

if n % 2 == 0:
	print(n + 2)
elif n % 2 != 0:
	print(n + 1)

# %% [markdown]
# # J. 100A
#
# ![image.png](data:image/png;base64,...)

# %%
print("A"*100)

# %% [markdown]
# # K. Пингвины
#
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())

pin = ["   _~_   ",
       "  (o o)  ",
       " /  V  \  ",
       "/(  _  )\ ",
       "  ^^ ^^  "]

for line in pin:
    print(line * n)

# %% [markdown]
# # L. 100 раз подряд в квадрате
#
# ![image.png](data:image/png;base64,...)

# %%
n = input()

n = str(n)
N = int(n * 100)
print(N ** 2)

# %% [markdown]
# # M. Разность времен
#
# ![image.png](data:image/png;base64,...)

# %%
hour1 = int(input()) * 3600
min1 = int(input()) * 60
sec1 = int(input())

hour2 = int(input()) * 3600
min2 = int(input()) * 60
sec2 = int(input())

print(hour2 + min2 + sec2 - hour1 - min1 - sec1)

# %% [markdown]
# # N. Стоимость покупки
#
# ![image.png](data:image/png;base64,...)

# %%
A = int(input())
B = int(input())
N = int(input())

full_money = N * (A * 100 + B)
print(full_money // 100, full_money % 100)

# %% [markdown]
# # O. МКАД
#
# ![image.png](data:image/png;base64,...)

# %%
v = int(input())
t = int(input())

s = v * t

print(s % 109)

# %% [markdown]
# # P. Электронные часы-1
#
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())

n = n % 1440

hour = n // 60
minute = n % 60

print(hour, minute)

# %% [markdown]
# # Q. Симметричное число*
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # R. Автопробег
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # S. Улитка*
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # T. Максимум из двух*
#
# ![image.png](data:image/png;base64,...)
